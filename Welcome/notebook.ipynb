# %% [markdown]
# ## 👋 Welcome to your workspace

# %% [markdown]
# This is an example of a notebook in your workspace. Your workspace is a home for you and your team's projects.

# %% [markdown]
# ### Playing around 🧸

# %% [markdown]
# We already got you started with a sample dataset which you can play around with...

# %%
df = _deepnote_execute_sql("""select
    *
from
    sessions
limit
    100
""", 'SQL_638EE43A_421F_4FAF_8344_13981F6A798A')
df
# Out:
#                              user_id        session_started_at  \
# 0   b2a2a973888c49379fc68dd8193123ec 2021-08-12 00:00:00+00:00
# 1   b2a2a973888c49379fc68dd8193123ec 2021-09-22 00:00:00+00:00
# 2   b2a2a973888c49379fc68dd8193123ec 2021-10-12 00:00:00+00:00
# 3   b2a2a973888c49379fc68dd8193123ec 2021-10-25 00:00:00+00:00
# 4   b2a2a973888c49379fc68dd8193123ec 2021-10-25 00:00:00+00:00
# ..                               ...                       ...
# 95  66112b87d2844c21af5f4e8d6e7e995e 2021-10-21 00:00:00+00:00
# 96  478ca47884184cc19c3c803c849032aa 2021-08-06 00:00:00+00:00
# 97  1754b2e09a4143858a1fca04ec6f6af1 2021-10-19 00:00:00+00:00
# 98  1754b2e09a4143858a1fca04ec6f6af1 2021-10-19 00:00:00+00:00
# 99  ff056d8b909b45e4b69c880c22e2ba12 2021-07-07 00:00:00+00:00
#
#     session_duration
# 0         982.068936
# 1         341.000005
# 2         349.962493
# 3         149.448095
# 4         651.690189
# ..               ...
# 95        786.385537
# 96        526.717193
# ...

# %% [markdown]
# You can even switch between SQL and Python...

# %%
df.session_duration.describe()
# Out:
# count     100.000000
# mean      529.689788
# std       328.252075
# min        36.473397
# 25%       280.407421
# 50%       455.107627
# 75%       693.984382
# max      1720.492292
# Name: session_duration, dtype: float64

# %% [markdown]
# And you can visualize your data easily, so you can generate insights faster...

# %%
DeepnoteChart(df, """{"data":{"name":"placeholder"},"mark":{"type":"bar","tooltip":true},"height":220,"$schema":"https://vega.github.io/schema/vega-lite/v4.json","autosize":{"type":"fit"},"encoding":{"x":{"bin":true,"sort":null,"type":"quantitative","field":"session_duration","scale":{"type":"linear","zero":false}},"y":{"sort":null,"type":"quantitative","field":"COUNT(*)","scale":{"type":"linear","zero":true},"aggregate":"count"},"color":{"sort":null,"type":"nominal","field":"","scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Next steps

# %% [markdown]
# 👈  Check out the left sidebar, it has some useful features:

# %% [markdown]
# 1. **Get creative**. You can play around with some sample notebooks we created for you. Let your imagination run wild 🧑‍🎨
# 1. **Connect your own data**. Visit the `Integrations` menu to connect your database or data warehouse.
# 1. **Work together**. Visit the `Settings` menu to add your team members and share insights with each other.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=278bea49-4652-449b-bfbd-9ff1443f7c1a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
